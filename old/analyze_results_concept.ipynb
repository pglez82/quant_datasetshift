# %%
import pandas as pd
import seaborn as sns
from IPython.display import display
import matplotlib.pyplot as plt
import os

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 150)

#Font size for the plots
plt.rcParams['font.size'] = '16'


export_dir = '/home/pgonzalez/Dropbox/quant_datasetshift/'
quantificators = ["CC", "ACC", "PCC", "PACC", "DyS", "SLD","MLPE"]
error = "MAE"
ps_train = [0.5]
ps_test = [0.25, 0.5, 0.75]
dateexperiment = "2022_09_26_14_58"


results_dict={}
print("Loading results... ",sep="")
for quant_name in quantificators:
    results_dict[quant_name] = pd.read_csv("results/concept/results_%s_%s.csv" % (dateexperiment,quant_name),index_col=0)
    results_dict[quant_name]['MAE'] = results_dict[quant_name]['error'].abs()
    results_dict[quant_name]['cut_points'] = results_dict[quant_name]['cut_point_train']-results_dict[quant_name]['cut_point_test']
print("Done")


mean_error_methods = {}

writer = pd.ExcelWriter('results/concept/excel/errors_%s.xlsx' % dateexperiment, engine='xlsxwriter')
for p_train in ps_train:
    for p_test in ps_test:
        for quant_name in quantificators:
            exp_id = "%s_%f_%f" % (quant_name,p_train,p_test)
            results = results_dict[quant_name]
            results = results.loc[(results['p_test'] == p_test) & (results['p_train'] == p_train)]
            results_mean = results.groupby(['cut_point_train', 'cut_point_test'])['MAE'].mean().reset_index()
            #convert to matrix form
            results_mean = results_mean.pivot(index='cut_point_train', columns='cut_point_test', values='MAE')
            mean_error_methods[exp_id]=results_mean.mean().mean()
            print("Results for method %s. p_train: %f. p_test: %f. %s: %f" % (quant_name,p_train, p_test,error,mean_error_methods[exp_id]))
            cm = sns.light_palette('red', as_cmap=True)
            display(results_mean.style.background_gradient(cmap=cm,low=0,high=1))
            results_mean.to_excel(writer, sheet_name=exp_id)
            workbook = writer.book
            worksheet = writer.sheets[exp_id]
            # Apply a conditional format to the cell range.
            worksheet.conditional_format('B2:D4', {'type': '2_color_scale','min_type':'num','max_type':'num','min_value':'0','max_value':'1','min_color':'#f3f0f0','max_color':'#ff0000'})
writer.close()
# Out:
# Loading results...
# Done
# Results for method CC. p_train: 0.500000. p_test: 0.250000. MAE: 0.132276
# <style type="text/css">
# #T_fe410_row0_col0, #T_fe410_row0_col1, #T_fe410_row0_col2, #T_fe410_row0_col3 {
#   background-color: #f97878;
#   color: #f1f1f1;
# }
# #T_fe410_row1_col0, #T_fe410_row2_col3 {
#   background-color: #f5c1c1;
#   color: #000000;
# }
# #T_fe410_row1_col1 {
#   background-color: #f6b6b6;
#   color: #000000;
# }
# #T_fe410_row1_col2 {
#   background-color: #f7a6a6;
#   color: #000000;
# }
# #T_fe410_row1_col3 {
#   background-color: #f79898;
#   color: #000000;
# }
# #T_fe410_row2_col0, #T_fe410_row3_col1, #T_fe410_row3_col2, #T_fe410_row3_col3 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_fe410_row2_col1 {
#   background-color: #f3e3e3;
#   color: #000000;
# }
# #T_fe410_row2_col2 {
#   background-color: #f4d0d0;
#   color: #000000;
# }
# #T_fe410_row3_col0 {
#   background-color: #f3efef;
#   color: #000000;
# }
# </style>
# <table id="T_fe410">
#   <thead>
#     <tr>
#       <th class="index_name level0" >cut_point_test</th>
#       <th id="T_fe410_level0_col0" class="col_heading level0 col0" >2</th>
#       <th id="T_fe410_level0_col1" class="col_heading level0 col1" >3</th>
#       <th id="T_fe410_level0_col2" class="col_heading level0 col2" >4</th>
#       <th id="T_fe410_level0_col3" class="col_heading level0 col3" >5</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cut_point_train</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fe410_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_fe410_row0_col0" class="data row0 col0" >0.080724</td>
#       <td id="T_fe410_row0_col1" class="data row0 col1" >0.156104</td>
#       <td id="T_fe410_row0_col2" class="data row0 col2" >0.268100</td>
#       <td id="T_fe410_row0_col3" class="data row0 col3" >0.408404</td>
#     </tr>
#     <tr>
#       <th id="T_fe410_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_fe410_row1_col0" class="data row1 col0" >0.042456</td>
#       <td id="T_fe410_row1_col1" class="data row1 col1" >0.085468</td>
#       <td id="T_fe410_row1_col2" class="data row1 col2" >0.175952</td>
#       <td id="T_fe410_row1_col3" class="data row1 col3" >0.332688</td>
#     </tr>
#     <tr>
#       <th id="T_fe410_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_fe410_row2_col0" class="data row2 col0" >0.017492</td>
#       <td id="T_fe410_row2_col1" class="data row2 col1" >0.033120</td>
#       <td id="T_fe410_row2_col2" class="data row2 col2" >0.089744</td>
#       <td id="T_fe410_row2_col3" class="data row2 col3" >0.239500</td>
#     </tr>
#     <tr>
#       <th id="T_fe410_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_fe410_row3_col0" class="data row3 col0" >0.017988</td>
#       <td id="T_fe410_row3_col1" class="data row3 col1" >0.017632</td>
#       <td id="T_fe410_row3_col2" class="data row3 col2" >0.023388</td>
#       <td id="T_fe410_row3_col3" class="data row3 col3" >0.127652</td>
#     </tr>
#   </tbody>
# </table>
# Results for method ACC. p_train: 0.500000. p_test: 0.250000. MAE: 0.167940
# <style type="text/css">
# #T_7a4b2_row0_col0, #T_7a4b2_row1_col1, #T_7a4b2_row2_col2, #T_7a4b2_row3_col3 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_7a4b2_row0_col1 {
#   background-color: #f5c0c0;
#   color: #000000;
# }
# #T_7a4b2_row0_col2, #T_7a4b2_row0_col3, #T_7a4b2_row3_col0, #T_7a4b2_row3_col1 {
#   background-color: #f97878;
#   color: #f1f1f1;
# }
# #T_7a4b2_row1_col0 {
#   background-color: #f4d8d7;
#   color: #000000;
# }
# #T_7a4b2_row1_col2, #T_7a4b2_row2_col3 {
#   background-color: #f6baba;
#   color: #000000;
# }
# #T_7a4b2_row1_col3 {
#   background-color: #f79595;
#   color: #000000;
# }
# #T_7a4b2_row2_col0 {
#   background-color: #f6b8b7;
#   color: #000000;
# }
# #T_7a4b2_row2_col1 {
#   background-color: #f5c8c8;
#   color: #000000;
# }
# #T_7a4b2_row3_col2 {
#   background-color: #f7a0a0;
#   color: #000000;
# }
# </style>
# <table id="T_7a4b2">
#   <thead>
#     <tr>
#       <th class="index_name level0" >cut_point_test</th>
#       <th id="T_7a4b2_level0_col0" class="col_heading level0 col0" >2</th>
#       <th id="T_7a4b2_level0_col1" class="col_heading level0 col1" >3</th>
#       <th id="T_7a4b2_level0_col2" class="col_heading level0 col2" >4</th>
#       <th id="T_7a4b2_level0_col3" class="col_heading level0 col3" >5</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cut_point_train</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a4b2_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_7a4b2_row0_col0" class="data row0 col0" >0.021589</td>
#       <td id="T_7a4b2_row0_col1" class="data row0 col1" >0.108862</td>
#       <td id="T_7a4b2_row0_col2" class="data row0 col2" >0.279194</td>
#       <td id="T_7a4b2_row0_col3" class="data row0 col3" >0.490890</td>
#     </tr>
#     <tr>
#       <th id="T_7a4b2_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_7a4b2_row1_col0" class="data row1 col0" >0.066029</td>
#       <td id="T_7a4b2_row1_col1" class="data row1 col1" >0.023631</td>
#       <td id="T_7a4b2_row1_col2" class="data row1 col2" >0.138789</td>
#       <td id="T_7a4b2_row1_col3" class="data row1 col3" >0.381237</td>
#     </tr>
#     <tr>
#       <th id="T_7a4b2_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_7a4b2_row2_col0" class="data row2 col0" >0.121368</td>
#       <td id="T_7a4b2_row2_col1" class="data row2 col1" >0.093579</td>
#       <td id="T_7a4b2_row2_col2" class="data row2 col2" >0.024414</td>
#       <td id="T_7a4b2_row2_col3" class="data row2 col3" >0.239106</td>
#     </tr>
#     <tr>
#       <th id="T_7a4b2_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_7a4b2_row3_col0" class="data row3 col0" >0.234168</td>
#       <td id="T_7a4b2_row3_col1" class="data row3 col1" >0.234021</td>
#       <td id="T_7a4b2_row3_col2" class="data row3 col2" >0.195329</td>
#       <td id="T_7a4b2_row3_col3" class="data row3 col3" >0.034831</td>
#     </tr>
#   </tbody>
# </table>
# Results for method PCC. p_train: 0.500000. p_test: 0.250000. MAE: 0.159106
# <style type="text/css">
# #T_05a4b_row0_col0, #T_05a4b_row0_col1, #T_05a4b_row0_col2, #T_05a4b_row0_col3 {
#   background-color: #f97878;
#   color: #f1f1f1;
# }
# #T_05a4b_row1_col0 {
#   background-color: #f5c1c1;
#   color: #000000;
# }
# #T_05a4b_row1_col1 {
#   background-color: #f6b2b2;
#   color: #000000;
# }
# #T_05a4b_row1_col2 {
#   background-color: #f7a5a5;
#   color: #000000;
# }
# #T_05a4b_row1_col3 {
#   background-color: #f79897;
#   color: #000000;
# }
# #T_05a4b_row2_col0 {
#   background-color: #f3e9e9;
#   color: #000000;
# }
# #T_05a4b_row2_col1 {
#   background-color: #f4dddd;
#   color: #000000;
# }
# #T_05a4b_row2_col2 {
#   background-color: #f4d2d2;
#   color: #000000;
# }
# #T_05a4b_row2_col3 {
#   background-color: #f5c2c2;
#   color: #000000;
# }
# #T_05a4b_row3_col0, #T_05a4b_row3_col1, #T_05a4b_row3_col2, #T_05a4b_row3_col3 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# </style>
# <table id="T_05a4b">
#   <thead>
#     <tr>
#       <th class="index_name level0" >cut_point_test</th>
#       <th id="T_05a4b_level0_col0" class="col_heading level0 col0" >2</th>
#       <th id="T_05a4b_level0_col1" class="col_heading level0 col1" >3</th>
#       <th id="T_05a4b_level0_col2" class="col_heading level0 col2" >4</th>
#       <th id="T_05a4b_level0_col3" class="col_heading level0 col3" >5</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cut_point_train</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05a4b_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_05a4b_row0_col0" class="data row0 col0" >0.121828</td>
#       <td id="T_05a4b_row0_col1" class="data row0 col1" >0.179911</td>
#       <td id="T_05a4b_row0_col2" class="data row0 col2" >0.265757</td>
#       <td id="T_05a4b_row0_col3" class="data row0 col3" >0.375293</td>
#     </tr>
#     <tr>
#       <th id="T_05a4b_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_05a4b_row1_col0" class="data row1 col0" >0.084176</td>
#       <td id="T_05a4b_row1_col1" class="data row1 col1" >0.122117</td>
#       <td id="T_05a4b_row1_col2" class="data row1 col2" >0.197291</td>
#       <td id="T_05a4b_row1_col3" class="data row1 col3" >0.319279</td>
#     </tr>
#     <tr>
#       <th id="T_05a4b_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_05a4b_row2_col0" class="data row2 col0" >0.063608</td>
#       <td id="T_05a4b_row2_col1" class="data row2 col1" >0.079756</td>
#       <td id="T_05a4b_row2_col2" class="data row2 col2" >0.128680</td>
#       <td id="T_05a4b_row2_col3" class="data row2 col3" >0.243700</td>
#     </tr>
#     <tr>
#       <th id="T_05a4b_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_05a4b_row3_col0" class="data row3 col0" >0.059899</td>
#       <td id="T_05a4b_row3_col1" class="data row3 col1" >0.060586</td>
#       <td id="T_05a4b_row3_col2" class="data row3 col2" >0.082752</td>
#       <td id="T_05a4b_row3_col3" class="data row3 col3" >0.161063</td>
#     </tr>
#   </tbody>
# </table>
# Results for method PACC. p_train: 0.500000. p_test: 0.250000. MAE: 0.175394
# <style type="text/css">
# #T_f2679_row0_col0, #T_f2679_row1_col1, #T_f2679_row2_col2, #T_f2679_row3_col3 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_f2679_row0_col1 {
#   background-color: #f5c3c3;
#   color: #000000;
# }
# #T_f2679_row0_col2, #T_f2679_row0_col3, #T_f2679_row3_col0, #T_f2679_row3_col1 {
#   background-color: #f97878;
#   color: #f1f1f1;
# }
# #T_f2679_row1_col0 {
#   background-color: #f4cfcf;
#   color: #000000;
# }
# #T_f2679_row1_col2 {
#   background-color: #f6b8b8;
#   color: #000000;
# }
# #T_f2679_row1_col3 {
#   background-color: #f79696;
#   color: #000000;
# }
# #T_f2679_row2_col0 {
#   background-color: #f6aeae;
#   color: #000000;
# }
# #T_f2679_row2_col1 {
#   background-color: #f5c1c1;
#   color: #000000;
# }
# #T_f2679_row2_col3 {
#   background-color: #f5bcbc;
#   color: #000000;
# }
# #T_f2679_row3_col2 {
#   background-color: #f89494;
#   color: #000000;
# }
# </style>
# <table id="T_f2679">
#   <thead>
#     <tr>
#       <th class="index_name level0" >cut_point_test</th>
#       <th id="T_f2679_level0_col0" class="col_heading level0 col0" >2</th>
#       <th id="T_f2679_level0_col1" class="col_heading level0 col1" >3</th>
#       <th id="T_f2679_level0_col2" class="col_heading level0 col2" >4</th>
#       <th id="T_f2679_level0_col3" class="col_heading level0 col3" >5</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cut_point_train</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f2679_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_f2679_row0_col0" class="data row0 col0" >0.020567</td>
#       <td id="T_f2679_row0_col1" class="data row0 col1" >0.108286</td>
#       <td id="T_f2679_row0_col2" class="data row0 col2" >0.280044</td>
#       <td id="T_f2679_row0_col3" class="data row0 col3" >0.498302</td>
#     </tr>
#     <tr>
#       <th id="T_f2679_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_f2679_row1_col0" class="data row1 col0" >0.084227</td>
#       <td id="T_f2679_row1_col1" class="data row1 col1" >0.022581</td>
#       <td id="T_f2679_row1_col2" class="data row1 col2" >0.141947</td>
#       <td id="T_f2679_row1_col3" class="data row1 col3" >0.385583</td>
#     </tr>
#     <tr>
#       <th id="T_f2679_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_f2679_row2_col0" class="data row2 col0" >0.145518</td>
#       <td id="T_f2679_row2_col1" class="data row2 col1" >0.111526</td>
#       <td id="T_f2679_row2_col2" class="data row2 col2" >0.023807</td>
#       <td id="T_f2679_row2_col3" class="data row2 col3" >0.235022</td>
#     </tr>
#     <tr>
#       <th id="T_f2679_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_f2679_row3_col0" class="data row3 col0" >0.247532</td>
#       <td id="T_f2679_row3_col1" class="data row3 col1" >0.246520</td>
#       <td id="T_f2679_row3_col2" class="data row3 col2" >0.220742</td>
#       <td id="T_f2679_row3_col3" class="data row3 col3" >0.034093</td>
#     </tr>
#   </tbody>
# </table>
# Results for method DyS. p_train: 0.500000. p_test: 0.250000. MAE: 0.155007
# <style type="text/css">
# #T_0a7b2_row0_col0, #T_0a7b2_row1_col1, #T_0a7b2_row2_col2, #T_0a7b2_row3_col3 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_0a7b2_row0_col1 {
#   background-color: #f6b8b8;
#   color: #000000;
# }
# #T_0a7b2_row0_col2, #T_0a7b2_row0_col3, #T_0a7b2_row3_col0, #T_0a7b2_row3_col1 {
#   background-color: #f97878;
#   color: #f1f1f1;
# }
# #T_0a7b2_row1_col0 {
#   background-color: #f4dddd;
#   color: #000000;
# }
# #T_0a7b2_row1_col2 {
#   background-color: #f6b8b7;
#   color: #000000;
# }
# #T_0a7b2_row1_col3 {
#   background-color: #f79595;
#   color: #000000;
# }
# #T_0a7b2_row2_col0 {
#   background-color: #f6b9b9;
#   color: #000000;
# }
# #T_0a7b2_row2_col1 {
#   background-color: #f5c9c9;
#   color: #000000;
# }
# #T_0a7b2_row2_col3 {
#   background-color: #f5bdbd;
#   color: #000000;
# }
# #T_0a7b2_row3_col2 {
#   background-color: #f6b0b0;
#   color: #000000;
# }
# </style>
# <table id="T_0a7b2">
#   <thead>
#     <tr>
#       <th class="index_name level0" >cut_point_test</th>
#       <th id="T_0a7b2_level0_col0" class="col_heading level0 col0" >2</th>
#       <th id="T_0a7b2_level0_col1" class="col_heading level0 col1" >3</th>
#       <th id="T_0a7b2_level0_col2" class="col_heading level0 col2" >4</th>
#       <th id="T_0a7b2_level0_col3" class="col_heading level0 col3" >5</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cut_point_train</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a7b2_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_0a7b2_row0_col0" class="data row0 col0" >0.018759</td>
#       <td id="T_0a7b2_row0_col1" class="data row0 col1" >0.099600</td>
#       <td id="T_0a7b2_row0_col2" class="data row0 col2" >0.270159</td>
#       <td id="T_0a7b2_row0_col3" class="data row0 col3" >0.491949</td>
#     </tr>
#     <tr>
#       <th id="T_0a7b2_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_0a7b2_row1_col0" class="data row1 col0" >0.047146</td>
#       <td id="T_0a7b2_row1_col1" class="data row1 col1" >0.020100</td>
#       <td id="T_0a7b2_row1_col2" class="data row1 col2" >0.139493</td>
#       <td id="T_0a7b2_row1_col3" class="data row1 col3" >0.384300</td>
#     </tr>
#     <tr>
#       <th id="T_0a7b2_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_0a7b2_row2_col0" class="data row2 col0" >0.100125</td>
#       <td id="T_0a7b2_row2_col1" class="data row2 col1" >0.076339</td>
#       <td id="T_0a7b2_row2_col2" class="data row2 col2" >0.021188</td>
#       <td id="T_0a7b2_row2_col3" class="data row2 col3" >0.231563</td>
#     </tr>
#     <tr>
#       <th id="T_0a7b2_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_0a7b2_row3_col0" class="data row3 col0" >0.196889</td>
#       <td id="T_0a7b2_row3_col1" class="data row3 col1" >0.192378</td>
#       <td id="T_0a7b2_row3_col2" class="data row3 col2" >0.154386</td>
#       <td id="T_0a7b2_row3_col3" class="data row3 col3" >0.035744</td>
#     </tr>
#   </tbody>
# </table>
# Results for method SLD. p_train: 0.500000. p_test: 0.250000. MAE: 0.153959
# <style type="text/css">
# #T_219a6_row0_col0, #T_219a6_row1_col1, #T_219a6_row2_col2, #T_219a6_row3_col3 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_219a6_row0_col1 {
#   background-color: #f6b5b5;
#   color: #000000;
# }
# #T_219a6_row0_col2, #T_219a6_row0_col3, #T_219a6_row3_col0, #T_219a6_row3_col1 {
#   background-color: #f97878;
#   color: #f1f1f1;
# }
# #T_219a6_row1_col0 {
#   background-color: #f4d2d2;
#   color: #000000;
# }
# #T_219a6_row1_col2 {
#   background-color: #f5bdbd;
#   color: #000000;
# }
# #T_219a6_row1_col3 {
#   background-color: #f79696;
#   color: #000000;
# }
# #T_219a6_row2_col0 {
#   background-color: #f6b3b3;
#   color: #000000;
# }
# #T_219a6_row2_col1 {
#   background-color: #f5c3c3;
#   color: #000000;
# }
# #T_219a6_row2_col3 {
#   background-color: #f5bebe;
#   color: #000000;
# }
# #T_219a6_row3_col2 {
#   background-color: #f6b6b6;
#   color: #000000;
# }
# </style>
# <table id="T_219a6">
#   <thead>
#     <tr>
#       <th class="index_name level0" >cut_point_test</th>
#       <th id="T_219a6_level0_col0" class="col_heading level0 col0" >2</th>
#       <th id="T_219a6_level0_col1" class="col_heading level0 col1" >3</th>
#       <th id="T_219a6_level0_col2" class="col_heading level0 col2" >4</th>
#       <th id="T_219a6_level0_col3" class="col_heading level0 col3" >5</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cut_point_train</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_219a6_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_219a6_row0_col0" class="data row0 col0" >0.017254</td>
#       <td id="T_219a6_row0_col1" class="data row0 col1" >0.098488</td>
#       <td id="T_219a6_row0_col2" class="data row0 col2" >0.279707</td>
#       <td id="T_219a6_row0_col3" class="data row0 col3" >0.503161</td>
#     </tr>
#     <tr>
#       <th id="T_219a6_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_219a6_row1_col0" class="data row1 col0" >0.058922</td>
#       <td id="T_219a6_row1_col1" class="data row1 col1" >0.019359</td>
#       <td id="T_219a6_row1_col2" class="data row1 col2" >0.129400</td>
#       <td id="T_219a6_row1_col3" class="data row1 col3" >0.385055</td>
#     </tr>
#     <tr>
#       <th id="T_219a6_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_219a6_row2_col0" class="data row2 col0" >0.102766</td>
#       <td id="T_219a6_row2_col1" class="data row2 col1" >0.080385</td>
#       <td id="T_219a6_row2_col2" class="data row2 col2" >0.019448</td>
#       <td id="T_219a6_row2_col3" class="data row2 col3" >0.228648</td>
#     </tr>
#     <tr>
#       <th id="T_219a6_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_219a6_row3_col0" class="data row3 col0" >0.183419</td>
#       <td id="T_219a6_row3_col1" class="data row3 col1" >0.179825</td>
#       <td id="T_219a6_row3_col2" class="data row3 col2" >0.147430</td>
#       <td id="T_219a6_row3_col3" class="data row3 col3" >0.030072</td>
#     </tr>
#   </tbody>
# </table>
# Results for method MLPE. p_train: 0.500000. p_test: 0.250000. MAE: 0.250000
# <style type="text/css">
# #T_9a857_row0_col0, #T_9a857_row0_col1, #T_9a857_row0_col2, #T_9a857_row0_col3, #T_9a857_row1_col0, #T_9a857_row1_col1, #T_9a857_row1_col2, #T_9a857_row1_col3, #T_9a857_row2_col0, #T_9a857_row2_col1, #T_9a857_row2_col2, #T_9a857_row2_col3, #T_9a857_row3_col0, #T_9a857_row3_col1, #T_9a857_row3_col2, #T_9a857_row3_col3 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# </style>
# <table id="T_9a857">
#   <thead>
#     <tr>
#       <th class="index_name level0" >cut_point_test</th>
#       <th id="T_9a857_level0_col0" class="col_heading level0 col0" >2</th>
#       <th id="T_9a857_level0_col1" class="col_heading level0 col1" >3</th>
#       <th id="T_9a857_level0_col2" class="col_heading level0 col2" >4</th>
#       <th id="T_9a857_level0_col3" class="col_heading level0 col3" >5</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cut_point_train</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a857_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_9a857_row0_col0" class="data row0 col0" >0.250000</td>
#       <td id="T_9a857_row0_col1" class="data row0 col1" >0.250000</td>
#       <td id="T_9a857_row0_col2" class="data row0 col2" >0.250000</td>
#       <td id="T_9a857_row0_col3" class="data row0 col3" >0.250000</td>
#     </tr>
#     <tr>
#       <th id="T_9a857_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_9a857_row1_col0" class="data row1 col0" >0.250000</td>
#       <td id="T_9a857_row1_col1" class="data row1 col1" >0.250000</td>
#       <td id="T_9a857_row1_col2" class="data row1 col2" >0.250000</td>
#       <td id="T_9a857_row1_col3" class="data row1 col3" >0.250000</td>
#     </tr>
#     <tr>
#       <th id="T_9a857_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_9a857_row2_col0" class="data row2 col0" >0.250000</td>
#       <td id="T_9a857_row2_col1" class="data row2 col1" >0.250000</td>
#       <td id="T_9a857_row2_col2" class="data row2 col2" >0.250000</td>
#       <td id="T_9a857_row2_col3" class="data row2 col3" >0.250000</td>
#     </tr>
#     <tr>
#       <th id="T_9a857_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_9a857_row3_col0" class="data row3 col0" >0.250000</td>
#       <td id="T_9a857_row3_col1" class="data row3 col1" >0.250000</td>
#       <td id="T_9a857_row3_col2" class="data row3 col2" >0.250000</td>
#       <td id="T_9a857_row3_col3" class="data row3 col3" >0.250000</td>
#     </tr>
#   </tbody>
# </table>
# Results for method CC. p_train: 0.500000. p_test: 0.500000. MAE: 0.089913
# <style type="text/css">
# #T_3480c_row0_col0, #T_3480c_row1_col1, #T_3480c_row2_col2, #T_3480c_row3_col3 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_3480c_row0_col1 {
#   background-color: #f5bcbc;
#   color: #000000;
# }
# #T_3480c_row0_col2, #T_3480c_row0_col3, #T_3480c_row3_col0, #T_3480c_row3_col1 {
#   background-color: #f97878;
#   color: #f1f1f1;
# }
# #T_3480c_row1_col0 {
#   background-color: #f4d4d4;
#   color: #000000;
# }
# #T_3480c_row1_col2 {
#   background-color: #f6b9b9;
#   color: #000000;
# }
# #T_3480c_row1_col3 {
#   background-color: #f79696;
#   color: #000000;
# }
# #T_3480c_row2_col0 {
#   background-color: #f6aaaa;
#   color: #000000;
# }
# #T_3480c_row2_col1 {
#   background-color: #f5c3c3;
#   color: #000000;
# }
# #T_3480c_row2_col3 {
#   background-color: #f5bdbd;
#   color: #000000;
# }
# #T_3480c_row3_col2 {
#   background-color: #f6adad;
#   color: #000000;
# }
# </style>
# <table id="T_3480c">
#   <thead>
#     <tr>
#       <th class="index_name level0" >cut_point_test</th>
#       <th id="T_3480c_level0_col0" class="col_heading level0 col0" >2</th>
#       <th id="T_3480c_level0_col1" class="col_heading level0 col1" >3</th>
#       <th id="T_3480c_level0_col2" class="col_heading level0 col2" >4</th>
#       <th id="T_3480c_level0_col3" class="col_heading level0 col3" >5</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cut_point_train</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3480c_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_3480c_row0_col0" class="data row0 col0" >0.013764</td>
#       <td id="T_3480c_row0_col1" class="data row0 col1" >0.064000</td>
#       <td id="T_3480c_row0_col2" class="data row0 col2" >0.145732</td>
#       <td id="T_3480c_row0_col3" class="data row0 col3" >0.242440</td>
#     </tr>
#     <tr>
#       <th id="T_3480c_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_3480c_row1_col0" class="data row1 col0" >0.044772</td>
#       <td id="T_3480c_row1_col1" class="data row1 col1" >0.015780</td>
#       <td id="T_3480c_row1_col2" class="data row1 col2" >0.074848</td>
#       <td id="T_3480c_row1_col3" class="data row1 col3" >0.186520</td>
#     </tr>
#     <tr>
#       <th id="T_3480c_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_3480c_row2_col0" class="data row2 col0" >0.088600</td>
#       <td id="T_3480c_row2_col1" class="data row2 col1" >0.058552</td>
#       <td id="T_3480c_row2_col2" class="data row2 col2" >0.015524</td>
#       <td id="T_3480c_row2_col3" class="data row2 col3" >0.112492</td>
#     </tr>
#     <tr>
#       <th id="T_3480c_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_3480c_row3_col0" class="data row3 col0" >0.142772</td>
#       <td id="T_3480c_row3_col1" class="data row3 col1" >0.127764</td>
#       <td id="T_3480c_row3_col2" class="data row3 col2" >0.088228</td>
#       <td id="T_3480c_row3_col3" class="data row3 col3" >0.016816</td>
#     </tr>
#   </tbody>
# </table>
# Results for method ACC. p_train: 0.500000. p_test: 0.500000. MAE: 0.148531
# <style type="text/css">
# #T_b737a_row0_col0, #T_b737a_row1_col1, #T_b737a_row2_col2, #T_b737a_row3_col3 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_b737a_row0_col1 {
#   background-color: #f5c8c8;
#   color: #000000;
# }
# #T_b737a_row0_col2, #T_b737a_row0_col3, #T_b737a_row3_col0, #T_b737a_row3_col1 {
#   background-color: #f97878;
#   color: #f1f1f1;
# }
# #T_b737a_row1_col0 {
#   background-color: #f4dbdb;
#   color: #000000;
# }
# #T_b737a_row1_col2 {
#   background-color: #f6b7b7;
#   color: #000000;
# }
# #T_b737a_row1_col3 {
#   background-color: #f89393;
#   color: #000000;
# }
# #T_b737a_row2_col0 {
#   background-color: #f6baba;
#   color: #000000;
# }
# #T_b737a_row2_col1 {
#   background-color: #f5cece;
#   color: #000000;
# }
# #T_b737a_row2_col3 {
#   background-color: #f6b9b9;
#   color: #000000;
# }
# #T_b737a_row3_col2 {
#   background-color: #f79696;
#   color: #000000;
# }
# </style>
# <table id="T_b737a">
#   <thead>
#     <tr>
#       <th class="index_name level0" >cut_point_test</th>
#       <th id="T_b737a_level0_col0" class="col_heading level0 col0" >2</th>
#       <th id="T_b737a_level0_col1" class="col_heading level0 col1" >3</th>
#       <th id="T_b737a_level0_col2" class="col_heading level0 col2" >4</th>
#       <th id="T_b737a_level0_col3" class="col_heading level0 col3" >5</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cut_point_train</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b737a_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_b737a_row0_col0" class="data row0 col0" >0.020909</td>
#       <td id="T_b737a_row0_col1" class="data row0 col1" >0.098066</td>
#       <td id="T_b737a_row0_col2" class="data row0 col2" >0.221982</td>
#       <td id="T_b737a_row0_col3" class="data row0 col3" >0.368065</td>
#     </tr>
#     <tr>
#       <th id="T_b737a_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_b737a_row1_col0" class="data row1 col0" >0.065017</td>
#       <td id="T_b737a_row1_col1" class="data row1 col1" >0.023706</td>
#       <td id="T_b737a_row1_col2" class="data row1 col2" >0.119105</td>
#       <td id="T_b737a_row1_col3" class="data row1 col3" >0.292489</td>
#     </tr>
#     <tr>
#       <th id="T_b737a_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_b737a_row2_col0" class="data row2 col0" >0.135917</td>
#       <td id="T_b737a_row2_col1" class="data row2 col1" >0.088227</td>
#       <td id="T_b737a_row2_col2" class="data row2 col2" >0.024291</td>
#       <td id="T_b737a_row2_col3" class="data row2 col3" >0.186460</td>
#     </tr>
#     <tr>
#       <th id="T_b737a_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_b737a_row3_col0" class="data row3 col0" >0.277386</td>
#       <td id="T_b737a_row3_col1" class="data row3 col1" >0.249506</td>
#       <td id="T_b737a_row3_col2" class="data row3 col2" >0.173900</td>
#       <td id="T_b737a_row3_col3" class="data row3 col3" >0.031470</td>
#     </tr>
#   </tbody>
# </table>
# Results for method PCC. p_train: 0.500000. p_test: 0.500000. MAE: 0.070514
# <style type="text/css">
# #T_b89b0_row0_col0, #T_b89b0_row1_col1, #T_b89b0_row2_col2, #T_b89b0_row3_col3 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_b89b0_row0_col1 {
#   background-color: #f6b5b5;
#   color: #000000;
# }
# #T_b89b0_row0_col2, #T_b89b0_row0_col3, #T_b89b0_row3_col0, #T_b89b0_row3_col1 {
#   background-color: #f97878;
#   color: #f1f1f1;
# }
# #T_b89b0_row1_col0 {
#   background-color: #f4d2d2;
#   color: #000000;
# }
# #T_b89b0_row1_col2, #T_b89b0_row3_col2 {
#   background-color: #f6b2b2;
#   color: #000000;
# }
# #T_b89b0_row1_col3 {
#   background-color: #f89292;
#   color: #000000;
# }
# #T_b89b0_row2_col0 {
#   background-color: #f7a6a6;
#   color: #000000;
# }
# #T_b89b0_row2_col1 {
#   background-color: #f5c1c1;
#   color: #000000;
# }
# #T_b89b0_row2_col3 {
#   background-color: #f6bbbb;
#   color: #000000;
# }
# </style>
# <table id="T_b89b0">
#   <thead>
#     <tr>
#       <th class="index_name level0" >cut_point_test</th>
#       <th id="T_b89b0_level0_col0" class="col_heading level0 col0" >2</th>
#       <th id="T_b89b0_level0_col1" class="col_heading level0 col1" >3</th>
#       <th id="T_b89b0_level0_col2" class="col_heading level0 col2" >4</th>
#       <th id="T_b89b0_level0_col3" class="col_heading level0 col3" >5</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cut_point_train</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b89b0_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_b89b0_row0_col0" class="data row0 col0" >0.009378</td>
#       <td id="T_b89b0_row0_col1" class="data row0 col1" >0.052778</td>
#       <td id="T_b89b0_row0_col2" class="data row0 col2" >0.116035</td>
#       <td id="T_b89b0_row0_col3" class="data row0 col3" >0.192817</td>
#     </tr>
#     <tr>
#       <th id="T_b89b0_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_b89b0_row1_col0" class="data row1 col0" >0.034016</td>
#       <td id="T_b89b0_row1_col1" class="data row1 col1" >0.011333</td>
#       <td id="T_b89b0_row1_col2" class="data row1 col2" >0.065250</td>
#       <td id="T_b89b0_row1_col3" class="data row1 col3" >0.153137</td>
#     </tr>
#     <tr>
#       <th id="T_b89b0_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_b89b0_row2_col0" class="data row2 col0" >0.069448</td>
#       <td id="T_b89b0_row2_col1" class="data row2 col1" >0.044392</td>
#       <td id="T_b89b0_row2_col2" class="data row2 col2" >0.010893</td>
#       <td id="T_b89b0_row2_col3" class="data row2 col3" >0.091144</td>
#     </tr>
#     <tr>
#       <th id="T_b89b0_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_b89b0_row3_col0" class="data row3 col0" >0.106468</td>
#       <td id="T_b89b0_row3_col1" class="data row3 col1" >0.094985</td>
#       <td id="T_b89b0_row3_col2" class="data row3 col2" >0.065296</td>
#       <td id="T_b89b0_row3_col3" class="data row3 col3" >0.010861</td>
#     </tr>
#   </tbody>
# </table>
# Results for method PACC. p_train: 0.500000. p_test: 0.500000. MAE: 0.156378
# <style type="text/css">
# #T_6b281_row0_col0, #T_6b281_row1_col1, #T_6b281_row2_col2, #T_6b281_row3_col3 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_6b281_row0_col1 {
#   background-color: #f5c8c8;
#   color: #000000;
# }
# #T_6b281_row0_col2, #T_6b281_row0_col3, #T_6b281_row3_col0, #T_6b281_row3_col1 {
#   background-color: #f97878;
#   color: #f1f1f1;
# }
# #T_6b281_row1_col0 {
#   background-color: #f4dada;
#   color: #000000;
# }
# #T_6b281_row1_col2 {
#   background-color: #f6b4b4;
#   color: #000000;
# }
# #T_6b281_row1_col3 {
#   background-color: #f89393;
#   color: #000000;
# }
# #T_6b281_row2_col0, #T_6b281_row2_col3 {
#   background-color: #f6b9b9;
#   color: #000000;
# }
# #T_6b281_row2_col1 {
#   background-color: #f5cccc;
#   color: #000000;
# }
# #T_6b281_row3_col2 {
#   background-color: #f89292;
#   color: #000000;
# }
# </style>
# <table id="T_6b281">
#   <thead>
#     <tr>
#       <th class="index_name level0" >cut_point_test</th>
#       <th id="T_6b281_level0_col0" class="col_heading level0 col0" >2</th>
#       <th id="T_6b281_level0_col1" class="col_heading level0 col1" >3</th>
#       <th id="T_6b281_level0_col2" class="col_heading level0 col2" >4</th>
#       <th id="T_6b281_level0_col3" class="col_heading level0 col3" >5</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cut_point_train</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6b281_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_6b281_row0_col0" class="data row0 col0" >0.018455</td>
#       <td id="T_6b281_row0_col1" class="data row0 col1" >0.103514</td>
#       <td id="T_6b281_row0_col2" class="data row0 col2" >0.230046</td>
#       <td id="T_6b281_row0_col3" class="data row0 col3" >0.382890</td>
#     </tr>
#     <tr>
#       <th id="T_6b281_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_6b281_row1_col0" class="data row1 col0" >0.070801</td>
#       <td id="T_6b281_row1_col1" class="data row1 col1" >0.022054</td>
#       <td id="T_6b281_row1_col2" class="data row1 col2" >0.127882</td>
#       <td id="T_6b281_row1_col3" class="data row1 col3" >0.303637</td>
#     </tr>
#     <tr>
#       <th id="T_6b281_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_6b281_row2_col0" class="data row2 col0" >0.148236</td>
#       <td id="T_6b281_row2_col1" class="data row2 col1" >0.095612</td>
#       <td id="T_6b281_row2_col2" class="data row2 col2" >0.022646</td>
#       <td id="T_6b281_row2_col3" class="data row2 col3" >0.191222</td>
#     </tr>
#     <tr>
#       <th id="T_6b281_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_6b281_row3_col0" class="data row3 col0" >0.300059</td>
#       <td id="T_6b281_row3_col1" class="data row3 col1" >0.268382</td>
#       <td id="T_6b281_row3_col2" class="data row3 col2" >0.185618</td>
#       <td id="T_6b281_row3_col3" class="data row3 col3" >0.030996</td>
#     </tr>
#   </tbody>
# </table>
# Results for method DyS. p_train: 0.500000. p_test: 0.500000. MAE: 0.144769
# <style type="text/css">
# #T_1a030_row0_col0, #T_1a030_row1_col1, #T_1a030_row2_col2, #T_1a030_row3_col3 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_1a030_row0_col1 {
#   background-color: #f5c5c5;
#   color: #000000;
# }
# #T_1a030_row0_col2, #T_1a030_row0_col3, #T_1a030_row3_col0, #T_1a030_row3_col1 {
#   background-color: #f97878;
#   color: #f1f1f1;
# }
# #T_1a030_row1_col0 {
#   background-color: #f4dcdc;
#   color: #000000;
# }
# #T_1a030_row1_col2 {
#   background-color: #f6b3b3;
#   color: #000000;
# }
# #T_1a030_row1_col3 {
#   background-color: #f89191;
#   color: #000000;
# }
# #T_1a030_row2_col0 {
#   background-color: #f6b7b7;
#   color: #000000;
# }
# #T_1a030_row2_col1 {
#   background-color: #f5cbcb;
#   color: #000000;
# }
# #T_1a030_row2_col3 {
#   background-color: #f6b9b9;
#   color: #000000;
# }
# #T_1a030_row3_col2 {
#   background-color: #f79b9b;
#   color: #000000;
# }
# </style>
# <table id="T_1a030">
#   <thead>
#     <tr>
#       <th class="index_name level0" >cut_point_test</th>
#       <th id="T_1a030_level0_col0" class="col_heading level0 col0" >2</th>
#       <th id="T_1a030_level0_col1" class="col_heading level0 col1" >3</th>
#       <th id="T_1a030_level0_col2" class="col_heading level0 col2" >4</th>
#       <th id="T_1a030_level0_col3" class="col_heading level0 col3" >5</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cut_point_train</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a030_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_1a030_row0_col0" class="data row0 col0" >0.020036</td>
#       <td id="T_1a030_row0_col1" class="data row0 col1" >0.098488</td>
#       <td id="T_1a030_row0_col2" class="data row0 col2" >0.221992</td>
#       <td id="T_1a030_row0_col3" class="data row0 col3" >0.361572</td>
#     </tr>
#     <tr>
#       <th id="T_1a030_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_1a030_row1_col0" class="data row1 col0" >0.059791</td>
#       <td id="T_1a030_row1_col1" class="data row1 col1" >0.023935</td>
#       <td id="T_1a030_row1_col2" class="data row1 col2" >0.125900</td>
#       <td id="T_1a030_row1_col3" class="data row1 col3" >0.293025</td>
#     </tr>
#     <tr>
#       <th id="T_1a030_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_1a030_row2_col0" class="data row2 col0" >0.133769</td>
#       <td id="T_1a030_row2_col1" class="data row2 col1" >0.087950</td>
#       <td id="T_1a030_row2_col2" class="data row2 col2" >0.023738</td>
#       <td id="T_1a030_row2_col3" class="data row2 col3" >0.183042</td>
#     </tr>
#     <tr>
#       <th id="T_1a030_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_1a030_row3_col0" class="data row3 col0" >0.257511</td>
#       <td id="T_1a030_row3_col1" class="data row3 col1" >0.230746</td>
#       <td id="T_1a030_row3_col2" class="data row3 col2" >0.163208</td>
#       <td id="T_1a030_row3_col3" class="data row3 col3" >0.031595</td>
#     </tr>
#   </tbody>
# </table>
# Results for method SLD. p_train: 0.500000. p_test: 0.500000. MAE: 0.147322
# <style type="text/css">
# #T_ad9f8_row0_col0, #T_ad9f8_row1_col1, #T_ad9f8_row2_col2, #T_ad9f8_row3_col3 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_ad9f8_row0_col1 {
#   background-color: #f5c0c0;
#   color: #000000;
# }
# #T_ad9f8_row0_col2, #T_ad9f8_row0_col3, #T_ad9f8_row3_col0, #T_ad9f8_row3_col1 {
#   background-color: #f97878;
#   color: #f1f1f1;
# }
# #T_ad9f8_row1_col0 {
#   background-color: #f4d8d8;
#   color: #000000;
# }
# #T_ad9f8_row1_col2 {
#   background-color: #f6b6b6;
#   color: #000000;
# }
# #T_ad9f8_row1_col3 {
#   background-color: #f89292;
#   color: #000000;
# }
# #T_ad9f8_row2_col0 {
#   background-color: #f6b5b5;
#   color: #000000;
# }
# #T_ad9f8_row2_col1 {
#   background-color: #f5c9c9;
#   color: #000000;
# }
# #T_ad9f8_row2_col3 {
#   background-color: #f6b8b8;
#   color: #000000;
# }
# #T_ad9f8_row3_col2 {
#   background-color: #f79c9c;
#   color: #000000;
# }
# </style>
# <table id="T_ad9f8">
#   <thead>
#     <tr>
#       <th class="index_name level0" >cut_point_test</th>
#       <th id="T_ad9f8_level0_col0" class="col_heading level0 col0" >2</th>
#       <th id="T_ad9f8_level0_col1" class="col_heading level0 col1" >3</th>
#       <th id="T_ad9f8_level0_col2" class="col_heading level0 col2" >4</th>
#       <th id="T_ad9f8_level0_col3" class="col_heading level0 col3" >5</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cut_point_train</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad9f8_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_ad9f8_row0_col0" class="data row0 col0" >0.018313</td>
#       <td id="T_ad9f8_row0_col1" class="data row0 col1" >0.106689</td>
#       <td id="T_ad9f8_row0_col2" class="data row0 col2" >0.233320</td>
#       <td id="T_ad9f8_row0_col3" class="data row0 col3" >0.366384</td>
#     </tr>
#     <tr>
#       <th id="T_ad9f8_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_ad9f8_row1_col0" class="data row1 col0" >0.066347</td>
#       <td id="T_ad9f8_row1_col1" class="data row1 col1" >0.021830</td>
#       <td id="T_ad9f8_row1_col2" class="data row1 col2" >0.125444</td>
#       <td id="T_ad9f8_row1_col3" class="data row1 col3" >0.292804</td>
#     </tr>
#     <tr>
#       <th id="T_ad9f8_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_ad9f8_row2_col0" class="data row2 col0" >0.137329</td>
#       <td id="T_ad9f8_row2_col1" class="data row2 col1" >0.090852</td>
#       <td id="T_ad9f8_row2_col2" class="data row2 col2" >0.020913</td>
#       <td id="T_ad9f8_row2_col3" class="data row2 col3" >0.184975</td>
#     </tr>
#     <tr>
#       <th id="T_ad9f8_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_ad9f8_row3_col0" class="data row3 col0" >0.260109</td>
#       <td id="T_ad9f8_row3_col1" class="data row3 col1" >0.234474</td>
#       <td id="T_ad9f8_row3_col2" class="data row3 col2" >0.169537</td>
#       <td id="T_ad9f8_row3_col3" class="data row3 col3" >0.027837</td>
#     </tr>
#   </tbody>
# </table>
# Results for method MLPE. p_train: 0.500000. p_test: 0.500000. MAE: 0.000000
# <style type="text/css">
# #T_e84d6_row0_col0, #T_e84d6_row0_col1, #T_e84d6_row0_col2, #T_e84d6_row0_col3, #T_e84d6_row1_col0, #T_e84d6_row1_col1, #T_e84d6_row1_col2, #T_e84d6_row1_col3, #T_e84d6_row2_col0, #T_e84d6_row2_col1, #T_e84d6_row2_col2, #T_e84d6_row2_col3, #T_e84d6_row3_col0, #T_e84d6_row3_col1, #T_e84d6_row3_col2, #T_e84d6_row3_col3 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# </style>
# <table id="T_e84d6">
#   <thead>
#     <tr>
#       <th class="index_name level0" >cut_point_test</th>
#       <th id="T_e84d6_level0_col0" class="col_heading level0 col0" >2</th>
#       <th id="T_e84d6_level0_col1" class="col_heading level0 col1" >3</th>
#       <th id="T_e84d6_level0_col2" class="col_heading level0 col2" >4</th>
#       <th id="T_e84d6_level0_col3" class="col_heading level0 col3" >5</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cut_point_train</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e84d6_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_e84d6_row0_col0" class="data row0 col0" >0.000000</td>
#       <td id="T_e84d6_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_e84d6_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_e84d6_row0_col3" class="data row0 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e84d6_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_e84d6_row1_col0" class="data row1 col0" >0.000000</td>
#       <td id="T_e84d6_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_e84d6_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_e84d6_row1_col3" class="data row1 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e84d6_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_e84d6_row2_col0" class="data row2 col0" >0.000000</td>
#       <td id="T_e84d6_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_e84d6_row2_col2" class="data row2 col2" >0.000000</td>
#       <td id="T_e84d6_row2_col3" class="data row2 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e84d6_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_e84d6_row3_col0" class="data row3 col0" >0.000000</td>
#       <td id="T_e84d6_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_e84d6_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_e84d6_row3_col3" class="data row3 col3" >0.000000</td>
#     </tr>
#   </tbody>
# </table>
# Results for method CC. p_train: 0.500000. p_test: 0.750000. MAE: 0.112844
# <style type="text/css">
# #T_7b722_row0_col0, #T_7b722_row0_col1, #T_7b722_row0_col2, #T_7b722_row2_col3 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_7b722_row0_col3 {
#   background-color: #f7a3a3;
#   color: #000000;
# }
# #T_7b722_row1_col0 {
#   background-color: #f4d2d2;
#   color: #000000;
# }
# #T_7b722_row1_col1 {
#   background-color: #f4d4d4;
#   color: #000000;
# }
# #T_7b722_row1_col2 {
#   background-color: #f3efef;
#   color: #000000;
# }
# #T_7b722_row1_col3 {
#   background-color: #f5cece;
#   color: #000000;
# }
# #T_7b722_row2_col0 {
#   background-color: #f6adad;
#   color: #000000;
# }
# #T_7b722_row2_col1 {
#   background-color: #f6aeae;
#   color: #000000;
# }
# #T_7b722_row2_col2 {
#   background-color: #f5c1c1;
#   color: #000000;
# }
# #T_7b722_row3_col0, #T_7b722_row3_col1, #T_7b722_row3_col2, #T_7b722_row3_col3 {
#   background-color: #f97878;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7b722">
#   <thead>
#     <tr>
#       <th class="index_name level0" >cut_point_test</th>
#       <th id="T_7b722_level0_col0" class="col_heading level0 col0" >2</th>
#       <th id="T_7b722_level0_col1" class="col_heading level0 col1" >3</th>
#       <th id="T_7b722_level0_col2" class="col_heading level0 col2" >4</th>
#       <th id="T_7b722_level0_col3" class="col_heading level0 col3" >5</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cut_point_train</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7b722_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_7b722_row0_col0" class="data row0 col0" >0.081872</td>
#       <td id="T_7b722_row0_col1" class="data row0 col1" >0.031936</td>
#       <td id="T_7b722_row0_col2" class="data row0 col2" >0.025508</td>
#       <td id="T_7b722_row0_col3" class="data row0 col3" >0.079192</td>
#     </tr>
#     <tr>
#       <th id="T_7b722_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_7b722_row1_col0" class="data row1 col0" >0.131892</td>
#       <td id="T_7b722_row1_col1" class="data row1 col1" >0.084588</td>
#       <td id="T_7b722_row1_col2" class="data row1 col2" >0.027400</td>
#       <td id="T_7b722_row1_col3" class="data row1 col3" >0.044160</td>
#     </tr>
#     <tr>
#       <th id="T_7b722_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_7b722_row2_col0" class="data row2 col0" >0.192292</td>
#       <td id="T_7b722_row2_col1" class="data row2 col1" >0.152288</td>
#       <td id="T_7b722_row2_col2" class="data row2 col2" >0.094508</td>
#       <td id="T_7b722_row2_col3" class="data row2 col3" >0.016436</td>
#     </tr>
#     <tr>
#       <th id="T_7b722_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_7b722_row3_col0" class="data row3 col0" >0.279348</td>
#       <td id="T_7b722_row3_col1" class="data row3 col1" >0.249628</td>
#       <td id="T_7b722_row3_col2" class="data row3 col2" >0.201048</td>
#       <td id="T_7b722_row3_col3" class="data row3 col3" >0.113412</td>
#     </tr>
#   </tbody>
# </table>
# Results for method ACC. p_train: 0.500000. p_test: 0.750000. MAE: 0.128583
# <style type="text/css">
# #T_d86c6_row0_col0, #T_d86c6_row1_col1, #T_d86c6_row2_col2, #T_d86c6_row3_col3 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_d86c6_row0_col1 {
#   background-color: #f4d2d2;
#   color: #000000;
# }
# #T_d86c6_row0_col2, #T_d86c6_row0_col3, #T_d86c6_row3_col0, #T_d86c6_row3_col1 {
#   background-color: #f97878;
#   color: #f1f1f1;
# }
# #T_d86c6_row1_col0 {
#   background-color: #f4dede;
#   color: #000000;
# }
# #T_d86c6_row1_col2 {
#   background-color: #f6b0b0;
#   color: #000000;
# }
# #T_d86c6_row1_col3 {
#   background-color: #f88a8a;
#   color: #f1f1f1;
# }
# #T_d86c6_row2_col0 {
#   background-color: #f6b9b9;
#   color: #000000;
# }
# #T_d86c6_row2_col1 {
#   background-color: #f4cfcf;
#   color: #000000;
# }
# #T_d86c6_row2_col3 {
#   background-color: #f6b1b1;
#   color: #000000;
# }
# #T_d86c6_row3_col2 {
#   background-color: #f97e7e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_d86c6">
#   <thead>
#     <tr>
#       <th class="index_name level0" >cut_point_test</th>
#       <th id="T_d86c6_level0_col0" class="col_heading level0 col0" >2</th>
#       <th id="T_d86c6_level0_col1" class="col_heading level0 col1" >3</th>
#       <th id="T_d86c6_level0_col2" class="col_heading level0 col2" >4</th>
#       <th id="T_d86c6_level0_col3" class="col_heading level0 col3" >5</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cut_point_train</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d86c6_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_d86c6_row0_col0" class="data row0 col0" >0.019311</td>
#       <td id="T_d86c6_row0_col1" class="data row0 col1" >0.082582</td>
#       <td id="T_d86c6_row0_col2" class="data row0 col2" >0.165312</td>
#       <td id="T_d86c6_row0_col3" class="data row0 col3" >0.239697</td>
#     </tr>
#     <tr>
#       <th id="T_d86c6_level0_row1" class="row_heading level0 row1" >3</th>
# ...
#     <tr>
#       <th id="T_d86c6_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_d86c6_row2_col0" class="data row2 col0" >0.151683</td>
#       <td id="T_d86c6_row2_col1" class="data row2 col1" >0.087635</td>
#       <td id="T_d86c6_row2_col2" class="data row2 col2" >0.024104</td>
#       <td id="T_d86c6_row2_col3" class="data row2 col3" >0.140887</td>
#     </tr>
#     <tr>
#       <th id="T_d86c6_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_d86c6_row3_col0" class="data row3 col0" >0.309632</td>
#       <td id="T_d86c6_row3_col1" class="data row3 col1" >0.253022</td>
#       <td id="T_d86c6_row3_col2" class="data row3 col2" >0.158077</td>
#       <td id="T_d86c6_row3_col3" class="data row3 col3" >0.029596</td>
#     </tr>
#   </tbody>
# </table>
# Results for method PCC. p_train: 0.500000. p_test: 0.750000. MAE: 0.127454
# <style type="text/css">
# #T_139bc_row0_col0, #T_139bc_row0_col1, #T_139bc_row0_col2, #T_139bc_row0_col3 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_139bc_row1_col0 {
#   background-color: #f4d5d5;
#   color: #000000;
# }
# #T_139bc_row1_col1 {
#   background-color: #f4d7d7;
#   color: #000000;
# }
# #T_139bc_row1_col2 {
#   background-color: #f4dada;
#   color: #000000;
# }
# #T_139bc_row1_col3 {
#   background-color: #f3eded;
#   color: #000000;
# }
# #T_139bc_row2_col0 {
#   background-color: #f6aeae;
#   color: #000000;
# }
# #T_139bc_row2_col1 {
#   background-color: #f6afaf;
#   color: #000000;
# }
# #T_139bc_row2_col2 {
#   background-color: #f6b4b4;
#   color: #000000;
# }
# #T_139bc_row2_col3 {
#   background-color: #f5caca;
#   color: #000000;
# }
# #T_139bc_row3_col0, #T_139bc_row3_col1, #T_139bc_row3_col2, #T_139bc_row3_col3 {
#   background-color: #f97878;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_139bc">
#   <thead>
#     <tr>
#       <th class="index_name level0" >cut_point_test</th>
#       <th id="T_139bc_level0_col0" class="col_heading level0 col0" >2</th>
#       <th id="T_139bc_level0_col1" class="col_heading level0 col1" >3</th>
#       <th id="T_139bc_level0_col2" class="col_heading level0 col2" >4</th>
#       <th id="T_139bc_level0_col3" class="col_heading level0 col3" >5</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cut_point_train</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_139bc_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_139bc_row0_col0" class="data row0 col0" >0.115363</td>
#       <td id="T_139bc_row0_col1" class="data row0 col1" >0.076489</td>
#       <td id="T_139bc_row0_col2" class="data row0 col2" >0.033597</td>
#       <td id="T_139bc_row0_col3" class="data row0 col3" >0.014442</td>
#     </tr>
#     <tr>
#       <th id="T_139bc_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_139bc_row1_col0" class="data row1 col0" >0.152193</td>
#       <td id="T_139bc_row1_col1" class="data row1 col1" >0.114397</td>
#       <td id="T_139bc_row1_col2" class="data row1 col2" >0.066818</td>
#       <td id="T_139bc_row1_col3" class="data row1 col3" >0.018612</td>
#     </tr>
#     <tr>
#       <th id="T_139bc_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_139bc_row2_col0" class="data row2 col0" >0.202524</td>
#       <td id="T_139bc_row2_col1" class="data row2 col1" >0.170635</td>
#       <td id="T_139bc_row2_col2" class="data row2 col2" >0.124526</td>
#       <td id="T_139bc_row2_col3" class="data row2 col3" >0.058321</td>
#     </tr>
#     <tr>
#       <th id="T_139bc_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_139bc_row3_col0" class="data row3 col0" >0.272639</td>
#       <td id="T_139bc_row3_col1" class="data row3 col1" >0.251069</td>
#       <td id="T_139bc_row3_col2" class="data row3 col2" >0.215320</td>
#       <td id="T_139bc_row3_col3" class="data row3 col3" >0.152322</td>
#     </tr>
#   </tbody>
# </table>
# Results for method PACC. p_train: 0.500000. p_test: 0.750000. MAE: 0.133136
# <style type="text/css">
# #T_baec8_row0_col0, #T_baec8_row1_col1, #T_baec8_row2_col2, #T_baec8_row3_col3 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_baec8_row0_col1 {
#   background-color: #f5cccc;
#   color: #000000;
# }
# #T_baec8_row0_col2, #T_baec8_row0_col3, #T_baec8_row3_col0, #T_baec8_row3_col1 {
#   background-color: #f97878;
#   color: #f1f1f1;
# }
# #T_baec8_row1_col0 {
#   background-color: #f4e2e2;
#   color: #000000;
# }
# #T_baec8_row1_col2 {
#   background-color: #f6acac;
#   color: #000000;
# }
# #T_baec8_row1_col3 {
#   background-color: #f88686;
#   color: #f1f1f1;
# }
# #T_baec8_row2_col0 {
#   background-color: #f6bbbb;
#   color: #000000;
# }
# #T_baec8_row2_col1 {
#   background-color: #f4d2d2;
#   color: #000000;
# }
# #T_baec8_row2_col3 {
#   background-color: #f6adad;
#   color: #000000;
# }
# #T_baec8_row3_col2 {
#   background-color: #f89090;
#   color: #000000;
# }
# </style>
# <table id="T_baec8">
#   <thead>
#     <tr>
#       <th class="index_name level0" >cut_point_test</th>
#       <th id="T_baec8_level0_col0" class="col_heading level0 col0" >2</th>
#       <th id="T_baec8_level0_col1" class="col_heading level0 col1" >3</th>
#       <th id="T_baec8_level0_col2" class="col_heading level0 col2" >4</th>
#       <th id="T_baec8_level0_col3" class="col_heading level0 col3" >5</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cut_point_train</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_baec8_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_baec8_row0_col0" class="data row0 col0" >0.022689</td>
#       <td id="T_baec8_row0_col1" class="data row0 col1" >0.094617</td>
#       <td id="T_baec8_row0_col2" class="data row0 col2" >0.180889</td>
#       <td id="T_baec8_row0_col3" class="data row0 col3" >0.247629</td>
#     </tr>
#     <tr>
#       <th id="T_baec8_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_baec8_row1_col0" class="data row1 col0" >0.057470</td>
#       <td id="T_baec8_row1_col1" class="data row1 col1" >0.026352</td>
#       <td id="T_baec8_row1_col2" class="data row1 col2" >0.113417</td>
#       <td id="T_baec8_row1_col3" class="data row1 col3" >0.223569</td>
#     </tr>
#     <tr>
#       <th id="T_baec8_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_baec8_row2_col0" class="data row2 col0" >0.151144</td>
#       <td id="T_baec8_row2_col1" class="data row2 col1" >0.084020</td>
#       <td id="T_baec8_row2_col2" class="data row2 col2" >0.024769</td>
#       <td id="T_baec8_row2_col3" class="data row2 col3" >0.153987</td>
#     </tr>
#     <tr>
#       <th id="T_baec8_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_baec8_row3_col0" class="data row3 col0" >0.311772</td>
#       <td id="T_baec8_row3_col1" class="data row3 col1" >0.250972</td>
#       <td id="T_baec8_row3_col2" class="data row3 col2" >0.149750</td>
#       <td id="T_baec8_row3_col3" class="data row3 col3" >0.037124</td>
#     </tr>
#   </tbody>
# </table>
# Results for method DyS. p_train: 0.500000. p_test: 0.750000. MAE: 0.123463
# <style type="text/css">
# #T_81db2_row0_col0, #T_81db2_row1_col1, #T_81db2_row2_col2, #T_81db2_row3_col3 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_81db2_row0_col1 {
#   background-color: #f4d4d4;
#   color: #000000;
# }
# #T_81db2_row0_col2 {
#   background-color: #f97c7c;
#   color: #f1f1f1;
# }
# #T_81db2_row0_col3, #T_81db2_row3_col0, #T_81db2_row3_col1, #T_81db2_row3_col2 {
#   background-color: #f97878;
#   color: #f1f1f1;
# }
# #T_81db2_row1_col0 {
#   background-color: #f4dddd;
#   color: #000000;
# }
# #T_81db2_row1_col2 {
#   background-color: #f6adad;
#   color: #000000;
# }
# #T_81db2_row1_col3 {
#   background-color: #f88989;
#   color: #f1f1f1;
# }
# #T_81db2_row2_col0 {
#   background-color: #f6b7b7;
#   color: #000000;
# }
# #T_81db2_row2_col1 {
#   background-color: #f5cbcb;
#   color: #000000;
# }
# #T_81db2_row2_col3 {
#   background-color: #f6b1b1;
#   color: #000000;
# }
# </style>
# <table id="T_81db2">
#   <thead>
#     <tr>
#       <th class="index_name level0" >cut_point_test</th>
#       <th id="T_81db2_level0_col0" class="col_heading level0 col0" >2</th>
#       <th id="T_81db2_level0_col1" class="col_heading level0 col1" >3</th>
#       <th id="T_81db2_level0_col2" class="col_heading level0 col2" >4</th>
#       <th id="T_81db2_level0_col3" class="col_heading level0 col3" >5</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cut_point_train</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_81db2_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_81db2_row0_col0" class="data row0 col0" >0.018587</td>
#       <td id="T_81db2_row0_col1" class="data row0 col1" >0.076362</td>
#       <td id="T_81db2_row0_col2" class="data row0 col2" >0.151842</td>
#       <td id="T_81db2_row0_col3" class="data row0 col3" >0.219567</td>
#     </tr>
#     <tr>
#       <th id="T_81db2_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_81db2_row1_col0" class="data row1 col0" >0.063841</td>
#       <td id="T_81db2_row1_col1" class="data row1 col1" >0.023035</td>
#       <td id="T_81db2_row1_col2" class="data row1 col2" >0.097630</td>
#       <td id="T_81db2_row1_col3" class="data row1 col3" >0.191637</td>
#     </tr>
#     <tr>
#       <th id="T_81db2_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_81db2_row2_col0" class="data row2 col0" >0.155946</td>
#       <td id="T_81db2_row2_col1" class="data row2 col1" >0.091781</td>
#       <td id="T_81db2_row2_col2" class="data row2 col2" >0.022546</td>
#       <td id="T_81db2_row2_col3" class="data row2 col3" >0.128371</td>
#     </tr>
#     <tr>
#       <th id="T_81db2_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_81db2_row3_col0" class="data row3 col0" >0.302576</td>
#       <td id="T_81db2_row3_col1" class="data row3 col1" >0.248052</td>
#       <td id="T_81db2_row3_col2" class="data row3 col2" >0.156862</td>
#       <td id="T_81db2_row3_col3" class="data row3 col3" >0.026777</td>
#     </tr>
#   </tbody>
# </table>
# Results for method SLD. p_train: 0.500000. p_test: 0.750000. MAE: 0.122575
# <style type="text/css">
# #T_472bc_row0_col0, #T_472bc_row1_col1, #T_472bc_row2_col2, #T_472bc_row3_col3 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_472bc_row0_col1 {
#   background-color: #f4d0d0;
#   color: #000000;
# }
# #T_472bc_row0_col2 {
#   background-color: #f97d7d;
#   color: #f1f1f1;
# }
# #T_472bc_row0_col3, #T_472bc_row3_col0, #T_472bc_row3_col1, #T_472bc_row3_col2 {
#   background-color: #f97878;
#   color: #f1f1f1;
# }
# #T_472bc_row1_col0 {
#   background-color: #f4dddd;
#   color: #000000;
# }
# #T_472bc_row1_col2 {
#   background-color: #f6b0b0;
#   color: #000000;
# }
# #T_472bc_row1_col3 {
#   background-color: #f88b8b;
#   color: #f1f1f1;
# }
# #T_472bc_row2_col0 {
#   background-color: #f6b8b7;
#   color: #000000;
# }
# #T_472bc_row2_col1 {
#   background-color: #f5cccc;
#   color: #000000;
# }
# #T_472bc_row2_col3 {
#   background-color: #f6afaf;
#   color: #000000;
# }
# </style>
# <table id="T_472bc">
#   <thead>
#     <tr>
#       <th class="index_name level0" >cut_point_test</th>
#       <th id="T_472bc_level0_col0" class="col_heading level0 col0" >2</th>
#       <th id="T_472bc_level0_col1" class="col_heading level0 col1" >3</th>
#       <th id="T_472bc_level0_col2" class="col_heading level0 col2" >4</th>
#       <th id="T_472bc_level0_col3" class="col_heading level0 col3" >5</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cut_point_train</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_472bc_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_472bc_row0_col0" class="data row0 col0" >0.018063</td>
#       <td id="T_472bc_row0_col1" class="data row0 col1" >0.082513</td>
#       <td id="T_472bc_row0_col2" class="data row0 col2" >0.152643</td>
#       <td id="T_472bc_row0_col3" class="data row0 col3" >0.209557</td>
#     </tr>
#     <tr>
#       <th id="T_472bc_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_472bc_row1_col0" class="data row1 col0" >0.065269</td>
#       <td id="T_472bc_row1_col1" class="data row1 col1" >0.020515</td>
#       <td id="T_472bc_row1_col2" class="data row1 col2" >0.094673</td>
#       <td id="T_472bc_row1_col3" class="data row1 col3" >0.179517</td>
#     </tr>
#     <tr>
#       <th id="T_472bc_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_472bc_row2_col0" class="data row2 col0" >0.155396</td>
#       <td id="T_472bc_row2_col1" class="data row2 col1" >0.091106</td>
#       <td id="T_472bc_row2_col2" class="data row2 col2" >0.020578</td>
#       <td id="T_472bc_row2_col3" class="data row2 col3" >0.125655</td>
#     </tr>
#     <tr>
#       <th id="T_472bc_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_472bc_row3_col0" class="data row3 col0" >0.308105</td>
#       <td id="T_472bc_row3_col1" class="data row3 col1" >0.253382</td>
#       <td id="T_472bc_row3_col2" class="data row3 col2" >0.158649</td>
#       <td id="T_472bc_row3_col3" class="data row3 col3" >0.025580</td>
#     </tr>
#   </tbody>
# </table>
# Results for method MLPE. p_train: 0.500000. p_test: 0.750000. MAE: 0.250000
# <style type="text/css">
# #T_a9f3d_row0_col0, #T_a9f3d_row0_col1, #T_a9f3d_row0_col2, #T_a9f3d_row0_col3, #T_a9f3d_row1_col0, #T_a9f3d_row1_col1, #T_a9f3d_row1_col2, #T_a9f3d_row1_col3, #T_a9f3d_row2_col0, #T_a9f3d_row2_col1, #T_a9f3d_row2_col2, #T_a9f3d_row2_col3, #T_a9f3d_row3_col0, #T_a9f3d_row3_col1, #T_a9f3d_row3_col2, #T_a9f3d_row3_col3 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# </style>
# <table id="T_a9f3d">
#   <thead>
#     <tr>
#       <th class="index_name level0" >cut_point_test</th>
#       <th id="T_a9f3d_level0_col0" class="col_heading level0 col0" >2</th>
#       <th id="T_a9f3d_level0_col1" class="col_heading level0 col1" >3</th>
#       <th id="T_a9f3d_level0_col2" class="col_heading level0 col2" >4</th>
#       <th id="T_a9f3d_level0_col3" class="col_heading level0 col3" >5</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >cut_point_train</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a9f3d_level0_row0" class="row_heading level0 row0" >2</th>
#       <td id="T_a9f3d_row0_col0" class="data row0 col0" >0.250000</td>
#       <td id="T_a9f3d_row0_col1" class="data row0 col1" >0.250000</td>
#       <td id="T_a9f3d_row0_col2" class="data row0 col2" >0.250000</td>
#       <td id="T_a9f3d_row0_col3" class="data row0 col3" >0.250000</td>
#     </tr>
#     <tr>
#       <th id="T_a9f3d_level0_row1" class="row_heading level0 row1" >3</th>
#       <td id="T_a9f3d_row1_col0" class="data row1 col0" >0.250000</td>
#       <td id="T_a9f3d_row1_col1" class="data row1 col1" >0.250000</td>
#       <td id="T_a9f3d_row1_col2" class="data row1 col2" >0.250000</td>
#       <td id="T_a9f3d_row1_col3" class="data row1 col3" >0.250000</td>
#     </tr>
#     <tr>
#       <th id="T_a9f3d_level0_row2" class="row_heading level0 row2" >4</th>
#       <td id="T_a9f3d_row2_col0" class="data row2 col0" >0.250000</td>
#       <td id="T_a9f3d_row2_col1" class="data row2 col1" >0.250000</td>
#       <td id="T_a9f3d_row2_col2" class="data row2 col2" >0.250000</td>
#       <td id="T_a9f3d_row2_col3" class="data row2 col3" >0.250000</td>
#     </tr>
#     <tr>
#       <th id="T_a9f3d_level0_row3" class="row_heading level0 row3" >5</th>
#       <td id="T_a9f3d_row3_col0" class="data row3 col0" >0.250000</td>
#       <td id="T_a9f3d_row3_col1" class="data row3 col1" >0.250000</td>
#       <td id="T_a9f3d_row3_col2" class="data row3 col2" >0.250000</td>
#       <td id="T_a9f3d_row3_col3" class="data row3 col3" >0.250000</td>
#     </tr>
#   </tbody>
# </table>

# %%
fig, ax = plt.subplots(len(ps_test)*len(ps_train),len(quantificators),figsize=(30,15))
plt.subplots_adjust(hspace=0.5)
for i, p_train in enumerate(ps_train):
    for j, p_test in enumerate(ps_test):
        for k,quant_name in enumerate(quantificators):
            exp_id = "%s_%f_%f" % (quant_name,p_train,p_test)
            row = i*len(ps_train)+j
            results = results_dict[quant_name]
            results = results.loc[(results['p_test'] == p_test) & (results['p_train'] == p_train)]
            ax[row][k].set_ylim(0, 1)
            ax[row][k].set_ylabel(error)
            results.boxplot(ax=ax[row][k],column='MAE',by='cut_points')
            plt.suptitle('Concept shift')
            ax[row][k].set_title("%s (%s: %f)"  % (quant_name,'MAE',mean_error_methods[exp_id]))
            plt.figtext(0.5,0.92-((i*len(ps_train)+j)*0.088), "p_train = %f, p_test = %f" % (p_train,p_test), ha="center", va="top", fontsize=14, color="b")

# %% [markdown]
# ### Tables and charts to be included in a paper

# %%
quantificators = ["CC", "ACC", "PCC", "PACC", "DyS", "SLD"]
for p_train in ps_train:
    for p_test in ps_test:
        fig, ax = plt.subplots(2,3,figsize=(15,8))
        plt.subplots_adjust(hspace=0.5)
        for k,quant_name in enumerate(quantificators):
            exp_id = "%s_%f_%f" % (quant_name,p_train,p_test)
            results = results_dict[quant_name]
            results = results.loc[(results['p_test'] == p_test) & (results['p_train'] == p_train)]
            ax[k//3][k%3].set_ylim(0, 1)
            ax[k//3][k%3].set_ylabel(error)
            results.boxplot(ax=ax[k//3][k%3],column='MAE',by='cut_points')
            plt.suptitle('Concept shift results with $p_{L}=%.2f$ and $p_{U}=%.2f$' % (p_train, p_test))
            ax[k//3][k%3].set_xlabel("Cut points train_test")
            ax[k//3][k%3].set_title("%s (%s: %f)"  % (quant_name,'MAE',mean_error_methods[exp_id]))
        #plt.savefig(os.path.join(export_dir,"images/conceptresults{}_{}.pdf".format(p_train,p_test)),format='pdf')
        #plt.savefig(os.path.join(export_dir("images/conceptresults{}_{}.png".format(p_train,p_test)),format='png')

# %% [markdown]
# ## Shorter version of charts (MAE version)

# %%
quantificators = ["PCC", "SLD"]

for i, p_train in enumerate(ps_train):
    fig = plt.figure(figsize=(15,8))
    subfigs = fig.subfigures(ncols=3,wspace=2)
    plt.subplots_adjust(hspace=0.6)

    for j, p_test in enumerate(ps_test):
        axs = subfigs[j].subplots(nrows=2)
        for k,quant_name in enumerate(quantificators):
            exp_id = "%s_%f_%f" % (quant_name,p_train,p_test)
            results = results_dict[quant_name]
            results = results.loc[(results['p_test'] == p_test) & (results['p_train'] == p_train)]
            axs[k].set_ylim(0, 1)
            axs[k].set_ylabel(error)
            results.boxplot(ax=axs[k],column='MAE',by='cut_points')
            axs[k].set_xlabel("Degree of concept shift")
            axs[k].set_title("%s (%s: %.3f)"  % (quant_name,error,mean_error_methods[exp_id]))
        subfigs[j].suptitle('$p_{L}=%.2f$, $p_{U}=%.2f$' % (p_train,p_test))
        if p_train==p_test:
            subfigs[j].set_facecolor('0.85')
        else:
            subfigs[j].set_facecolor('0.97')

    plt.savefig(os.path.join(export_dir,"images/conceptsummary_{}.pdf".format(p_train)),format='pdf',bbox_inches='tight')
    plt.savefig(os.path.join(export_dir,"images/conceptsummary_{}.png".format(p_train)),format='png',bbox_inches='tight')

# %% [markdown]
# ## Main tables for concept shift in the paper (version with AE)
#
# This table has the results for concept shift. It is meant to be in the main paper.

# %%
from utils.wilcoxon import wilcoxon_test

quantificators = ["CC", "ACC", "PCC", "PACC", "DyS", "SLD"]
global_results = {}
for i, p_train in enumerate(ps_train):
    columns = pd.MultiIndex.from_product([["p_test={}".format(p_test) for p_test in ps_test],quantificators])
    global_results[p_train] = pd.DataFrame(columns = columns,index=[-2,-1,0,1,2])
    for i, p_test in enumerate(ps_test):
        for k,quant_name in enumerate(quantificators):
            exp_id = "%s_%f_%f" % (quant_name,p_train,p_test)
            results = results_dict[quant_name]
            results = results.loc[(results['p_test'] == p_test) & (results['p_train'] == p_train)]
            results = results.groupby(by=['cut_points'])['MAE'].mean()
            global_results[p_train].loc[:, (["p_test={}".format(p_test)], [quant_name])] = results

global_results_style = {}
for p_train in ps_train:
    global_results_style[p_train] = global_results[p_train].style.format('{:.3f}')

for p_train in ps_train:
    for p_test in ps_test:
        #We want to make a statistical test for each row, to compare methods for the same degree of covariate shift
        for _,r in global_results[p_train].loc[:, (["p_test={}".format(p_test)])].iterrows():
            #compute the best method for this experiment
            cut_points = r.name
            best = r.index[r.argmin()]
            p_test = float(best[0][7:])
            best_method = best[1]
            #print("Computing statistical test for experiment covariate degree=%f, p_test=%s. Winner method %s" % (covariate_measure,p_test,best_method))
            #Get data for the winner method
            results_best = results_dict[best_method].loc[(results_dict[best_method]['p_test']==p_test) & (results_dict[best_method]['p_train']==p_train) & (results_dict[best_method]['cut_points']==cut_points),'error'].to_numpy()
            #We need to get all the rows in results that matches this experiment for each method
            for quant_name in quantificators:
                if quant_name!=best_method:
                    #print("Comparing %s with %s" % (best_method,quant_name))
                    results_method = results_dict[quant_name].loc[(results_dict[quant_name]['p_test']==p_test) & (results_dict[quant_name]['p_train']==p_train) & (results_dict[quant_name]['cut_points']==cut_points),'error'].to_numpy()
                    global_results_style[p_train].set_properties(subset=(cut_points, (best[0],quant_name)),**wilcoxon_test(results_best,results_method))


for p_train in ps_train:
    print("Table for p_train=%.2f" % p_train)
    for p_test in ps_test:
        global_results_style[p_train] = global_results_style[p_train].highlight_min(axis=1,props='textbf:--rwrap;',subset=(["p_test={}".format(p_test)]))
        if p_test == p_train:
            global_results_style[p_train] = global_results_style[p_train].set_properties(cellcolor="{verylightgray}", subset=(["p_test={}".format(p_test)]))
    display(global_results_style[p_train])
    columns = 'r'*len(quantificators)
    latex_code = global_results_style[p_train].to_latex(hrules=True,multicol_align='c',column_format='r|'+columns+'|'+columns+'|'+columns)
    latex_code = latex_code.replace(' 0.',' .').replace('{0.','{.')
    for p_test in ps_test:
        latex_code = latex_code.replace("p_test=%g" % p_test,"$p_{U}=%g$" % p_test)
    with open(os.path.join(export_dir,'tables/concept_table_{}.tex'.format(p_train)), 'w') as f:
        f.write(latex_code)
# Out:
# Table for p_train=0.50
# <style type="text/css">
# #T_a8a48_row0_col2, #T_a8a48_row0_col14, #T_a8a48_row1_col5, #T_a8a48_row1_col12, #T_a8a48_row2_col5, #T_a8a48_row2_col17, #T_a8a48_row3_col0, #T_a8a48_row3_col15, #T_a8a48_row4_col0, #T_a8a48_row4_col15 {
#   textbf: --rwrap;
# }
# #T_a8a48_row0_col6, #T_a8a48_row0_col7, #T_a8a48_row0_col9, #T_a8a48_row0_col10, #T_a8a48_row0_col11, #T_a8a48_row1_col6, #T_a8a48_row1_col7, #T_a8a48_row1_col9, #T_a8a48_row1_col10, #T_a8a48_row1_col11, #T_a8a48_row2_col6, #T_a8a48_row2_col9, #T_a8a48_row2_col10, #T_a8a48_row2_col11, #T_a8a48_row3_col6, #T_a8a48_row3_col7, #T_a8a48_row3_col9, #T_a8a48_row3_col10, #T_a8a48_row3_col11, #T_a8a48_row4_col6, #T_a8a48_row4_col7, #T_a8a48_row4_col9, #T_a8a48_row4_col10, #T_a8a48_row4_col11 {
#   cellcolor: {verylightgray};
# }
# #T_a8a48_row0_col8, #T_a8a48_row1_col8, #T_a8a48_row2_col8, #T_a8a48_row3_col8, #T_a8a48_row4_col8 {
#   textbf: --rwrap;
#   cellcolor: {verylightgray};
# }
# #T_a8a48_row2_col7 {
#   ddag: --rwrap;
#   cellcolor: {verylightgray};
# }
# #T_a8a48_row2_col13, #T_a8a48_row4_col13, #T_a8a48_row4_col16 {
#   ddag: --rwrap;
# }
# </style>
# <table id="T_a8a48">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a8a48_level0_col0" class="col_heading level0 col0" colspan="6">p_test=0.25</th>
#       <th id="T_a8a48_level0_col6" class="col_heading level0 col6" colspan="6">p_test=0.5</th>
#       <th id="T_a8a48_level0_col12" class="col_heading level0 col12" colspan="6">p_test=0.75</th>
#     </tr>
#     <tr>
#       <th class="blank level1" >&nbsp;</th>
#       <th id="T_a8a48_level1_col0" class="col_heading level1 col0" >CC</th>
#       <th id="T_a8a48_level1_col1" class="col_heading level1 col1" >ACC</th>
#       <th id="T_a8a48_level1_col2" class="col_heading level1 col2" >PCC</th>
#       <th id="T_a8a48_level1_col3" class="col_heading level1 col3" >PACC</th>
#       <th id="T_a8a48_level1_col4" class="col_heading level1 col4" >DyS</th>
#       <th id="T_a8a48_level1_col5" class="col_heading level1 col5" >SLD</th>
#       <th id="T_a8a48_level1_col6" class="col_heading level1 col6" >CC</th>
#       <th id="T_a8a48_level1_col7" class="col_heading level1 col7" >ACC</th>
#       <th id="T_a8a48_level1_col8" class="col_heading level1 col8" >PCC</th>
#       <th id="T_a8a48_level1_col9" class="col_heading level1 col9" >PACC</th>
#       <th id="T_a8a48_level1_col10" class="col_heading level1 col10" >DyS</th>
#       <th id="T_a8a48_level1_col11" class="col_heading level1 col11" >SLD</th>
#       <th id="T_a8a48_level1_col12" class="col_heading level1 col12" >CC</th>
#       <th id="T_a8a48_level1_col13" class="col_heading level1 col13" >ACC</th>
#       <th id="T_a8a48_level1_col14" class="col_heading level1 col14" >PCC</th>
#       <th id="T_a8a48_level1_col15" class="col_heading level1 col15" >PACC</th>
#       <th id="T_a8a48_level1_col16" class="col_heading level1 col16" >DyS</th>
#       <th id="T_a8a48_level1_col17" class="col_heading level1 col17" >SLD</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a8a48_level0_row0" class="row_heading level0 row0" >-2</th>
#       <td id="T_a8a48_row0_col0" class="data row0 col0" >0.300</td>
#       <td id="T_a8a48_row0_col1" class="data row0 col1" >0.330</td>
#       <td id="T_a8a48_row0_col2" class="data row0 col2" >0.293</td>
#       <td id="T_a8a48_row0_col3" class="data row0 col3" >0.333</td>
#       <td id="T_a8a48_row0_col4" class="data row0 col4" >0.327</td>
#       <td id="T_a8a48_row0_col5" class="data row0 col5" >0.332</td>
#       <td id="T_a8a48_row0_col6" class="data row0 col6" >0.166</td>
#       <td id="T_a8a48_row0_col7" class="data row0 col7" >0.257</td>
#       <td id="T_a8a48_row0_col8" class="data row0 col8" >0.135</td>
#       <td id="T_a8a48_row0_col9" class="data row0 col9" >0.267</td>
#       <td id="T_a8a48_row0_col10" class="data row0 col10" >0.258</td>
#       <td id="T_a8a48_row0_col11" class="data row0 col11" >0.263</td>
#       <td id="T_a8a48_row0_col12" class="data row0 col12" >0.035</td>
#       <td id="T_a8a48_row0_col13" class="data row0 col13" >0.187</td>
#       <td id="T_a8a48_row0_col14" class="data row0 col14" >0.026</td>
#       <td id="T_a8a48_row0_col15" class="data row0 col15" >0.202</td>
#       <td id="T_a8a48_row0_col16" class="data row0 col16" >0.172</td>
#       <td id="T_a8a48_row0_col17" class="data row0 col17" >0.166</td>
#     </tr>
#     <tr>
#       <th id="T_a8a48_level0_row1" class="row_heading level0 row1" >-1</th>
#       <td id="T_a8a48_row1_col0" class="data row1 col0" >0.191</td>
#       <td id="T_a8a48_row1_col1" class="data row1 col1" >0.162</td>
#       <td id="T_a8a48_row1_col2" class="data row1 col2" >0.207</td>
#       <td id="T_a8a48_row1_col3" class="data row1 col3" >0.162</td>
#       <td id="T_a8a48_row1_col4" class="data row1 col4" >0.157</td>
#       <td id="T_a8a48_row1_col5" class="data row1 col5" >0.152</td>
#       <td id="T_a8a48_row1_col6" class="data row1 col6" >0.084</td>
#       <td id="T_a8a48_row1_col7" class="data row1 col7" >0.135</td>
#       <td id="T_a8a48_row1_col8" class="data row1 col8" >0.070</td>
#       <td id="T_a8a48_row1_col9" class="data row1 col9" >0.141</td>
#       <td id="T_a8a48_row1_col10" class="data row1 col10" >0.136</td>
#       <td id="T_a8a48_row1_col11" class="data row1 col11" >0.139</td>
#       <td id="T_a8a48_row1_col12" class="data row1 col12" >0.025</td>
#       <td id="T_a8a48_row1_col13" class="data row1 col13" >0.108</td>
#       <td id="T_a8a48_row1_col14" class="data row1 col14" >0.067</td>
#       <td id="T_a8a48_row1_col15" class="data row1 col15" >0.121</td>
#       <td id="T_a8a48_row1_col16" class="data row1 col16" >0.101</td>
#       <td id="T_a8a48_row1_col17" class="data row1 col17" >0.101</td>
#     </tr>
#     <tr>
#       <th id="T_a8a48_level0_row2" class="row_heading level0 row2" >0</th>
#       <td id="T_a8a48_row2_col0" class="data row2 col0" >0.096</td>
#       <td id="T_a8a48_row2_col1" class="data row2 col1" >0.026</td>
#       <td id="T_a8a48_row2_col2" class="data row2 col2" >0.133</td>
#       <td id="T_a8a48_row2_col3" class="data row2 col3" >0.025</td>
#       <td id="T_a8a48_row2_col4" class="data row2 col4" >0.024</td>
#       <td id="T_a8a48_row2_col5" class="data row2 col5" >0.022</td>
#       <td id="T_a8a48_row2_col6" class="data row2 col6" >0.015</td>
#       <td id="T_a8a48_row2_col7" class="data row2 col7" >0.025</td>
#       <td id="T_a8a48_row2_col8" class="data row2 col8" >0.011</td>
#       <td id="T_a8a48_row2_col9" class="data row2 col9" >0.024</td>
#       <td id="T_a8a48_row2_col10" class="data row2 col10" >0.025</td>
#       <td id="T_a8a48_row2_col11" class="data row2 col11" >0.022</td>
#       <td id="T_a8a48_row2_col12" class="data row2 col12" >0.094</td>
#       <td id="T_a8a48_row2_col13" class="data row2 col13" >0.024</td>
#       <td id="T_a8a48_row2_col14" class="data row2 col14" >0.127</td>
#       <td id="T_a8a48_row2_col15" class="data row2 col15" >0.028</td>
#       <td id="T_a8a48_row2_col16" class="data row2 col16" >0.023</td>
#       <td id="T_a8a48_row2_col17" class="data row2 col17" >0.021</td>
#     </tr>
#     <tr>
#       <th id="T_a8a48_level0_row3" class="row_heading level0 row3" >1</th>
#       <td id="T_a8a48_row3_col0" class="data row3 col0" >0.033</td>
#       <td id="T_a8a48_row3_col1" class="data row3 col1" >0.118</td>
#       <td id="T_a8a48_row3_col2" class="data row3 col2" >0.082</td>
#       <td id="T_a8a48_row3_col3" class="data row3 col3" >0.139</td>
#       <td id="T_a8a48_row3_col4" class="data row3 col4" >0.093</td>
#       <td id="T_a8a48_row3_col5" class="data row3 col5" >0.096</td>
#       <td id="T_a8a48_row3_col6" class="data row3 col6" >0.064</td>
#       <td id="T_a8a48_row3_col7" class="data row3 col7" >0.109</td>
#       <td id="T_a8a48_row3_col8" class="data row3 col8" >0.048</td>
#       <td id="T_a8a48_row3_col9" class="data row3 col9" >0.117</td>
#       <td id="T_a8a48_row3_col10" class="data row3 col10" >0.104</td>
#       <td id="T_a8a48_row3_col11" class="data row3 col11" >0.109</td>
#       <td id="T_a8a48_row3_col12" class="data row3 col12" >0.162</td>
#       <td id="T_a8a48_row3_col13" class="data row3 col13" >0.103<
